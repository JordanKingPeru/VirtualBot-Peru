# %%
from bs4 import BeautifulSoup
import re
import urllib3
import certifi
import pandas as pd
from urllib.parse import quote
from selenium import webdriver
import json
from pandas.io.json import json_normalize

from datetime import datetime
import requests

from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
#se define la función word_concat_search cuyo objetivo es concatenar las palabras que se van a incluir en la búsqueda en su propio formato. Por ejemplo:
# se buscan las palabras 'tra' y 'mtc'. Como resultado se obtiene'tra%20mtc'
def word_concat_search(word_search):
    return pd.DataFrame({'word':word_search}).apply('%20'.join)['word']

def number_web_search(html):
    len_page = len(html.find('table').find('ul',attrs={'class':'pagination'}).find_all('li'))
    return len_page-2

def conexion_inicial(word_search,pag=1):
    busqueda = word_concat_search(word_search)
    url = "https://www.tramites.gob.pe/buscador/psce_tramites_buscador.aspx?txt_busqueda_general="+busqueda+"&pag="+str(pag)
    r = requests.get(url , verify=False)
    if (r.status_code==200):
        print('Conectado')
        html = BeautifulSoup(r.text, "html.parser")
        return html
    else: print('no se conectó')

# %%
word_search = ['tra','mtc']
html=conexion_inicial(word_search)

nw = number_web_search(html)
print('Se identificaron ',nw,' páginas para scraping')
# Out:
# Conectado
# Se identificaron  274  páginas para scraping

# %%
number_search = [] ; id_link = [] ; words = [] ;time=[] ; link = [] ; tramite=[] ; ministerio=[]
for j in range(nw):
    print(j,word_search)
    print(str(datetime.now()))
    html=conexion_inicial(word_search,pag=j+1)
    n_tr=len(html.find('table').find_all('tr'))
    listado_tramites = html.find('table').find_all('tr')[1:n_tr-1]

    for i in range(len(listado_tramites)):
        number_search.append(j)
        id_link.append(i)
        words.append(word_concat_search(word_search))
        time.append(str(datetime.now()))
        
        try: link.append('https://www.tramites.gob.pe/buscador/'+listado_tramites[i].find('a')['href'])
        except: link.append('Sin página')

        try: tramite.append(listado_tramites[i].find('a').text)
        except: tramite.append('Sin trámite')

        try: ministerio.append(listado_tramites[i].find_all('td')[1].text)
        except: ministerio.append('sin ministerio')

df_tramites_link=pd.DataFrame({'id_search':number_search,'word_key':words,'id_link':id_link,'link':link, 
                               'tramite':tramite,'ministerio':ministerio,'time_update':time})
# Out:
# 0 ['tra', 'mtc']
# 2019-09-14 12:28:06.844718
# Conectado
# 1 ['tra', 'mtc']
# 2019-09-14 12:28:09.906378
# Conectado
# 2 ['tra', 'mtc']
# 2019-09-14 12:28:14.023023
# Conectado
# 3 ['tra', 'mtc']
# 2019-09-14 12:28:18.451886
# Conectado
# 4 ['tra', 'mtc']
# 2019-09-14 12:28:21.749491
# Conectado
# 5 ['tra', 'mtc']
# 2019-09-14 12:28:23.941251
# Conectado
# 6 ['tra', 'mtc']
# 2019-09-14 12:28:27.477566
# Conectado
# 7 ['tra', 'mtc']
# 2019-09-14 12:28:30.281081
# Conectado
# 8 ['tra', 'mtc']
# 2019-09-14 12:28:32.606941
# Conectado
# 9 ['tra', 'mtc']
# 2019-09-14 12:28:36.349654
# Conectado
# 10 ['tra', 'mtc']
# 2019-09-14 12:28:39.332441
# Conectado
# 11 ['tra', 'mtc']
# 2019-09-14 12:28:42.010601
# Conectado
# 12 ['tra', 'mtc']
# 2019-09-14 12:28:45.059900
# Conectado
# 13 ['tra', 'mtc']
# 2019-09-14 12:28:47.866342
# Conectado
# 14 ['tra', 'mtc']
# 2019-09-14 12:28:51.480055
# Conectado
# 15 ['tra', 'mtc']
# 2019-09-14 12:28:55.852642
# Conectado
# 16 ['tra', 'mtc']
# 2019-09-14 12:29:00.010781
# Conectado
# 17 ['tra', 'mtc']
# 2019-09-14 12:29:04.635413
# Conectado
# 18 ['tra', 'mtc']
# 2019-09-14 12:29:07.748887
# Conectado
# 19 ['tra', 'mtc']
# 2019-09-14 12:29:13.093443
# Conectado
# 20 ['tra', 'mtc']
# 2019-09-14 12:29:16.981235
# Conectado
# 21 ['tra', 'mtc']
# 2019-09-14 12:29:19.363773
# Conectado
# 22 ['tra', 'mtc']
# 2019-09-14 12:29:21.818642
# Conectado
# 23 ['tra', 'mtc']
# 2019-09-14 12:29:24.011428
# Conectado
# 24 ['tra', 'mtc']
# 2019-09-14 12:29:26.168681
# Conectado
# 25 ['tra', 'mtc']
# 2019-09-14 12:29:28.345712
# Conectado
# 26 ['tra', 'mtc']
# 2019-09-14 12:29:30.679269
# Conectado
# 27 ['tra', 'mtc']
# 2019-09-14 12:29:32.840794
# Conectado
# 28 ['tra', 'mtc']
# 2019-09-14 12:29:34.994668
# Conectado
# 29 ['tra', 'mtc']
# 2019-09-14 12:29:37.202580
# Conectado
# 30 ['tra', 'mtc']
# 2019-09-14 12:29:39.404330
# Conectado
# 31 ['tra', 'mtc']
# 2019-09-14 12:29:41.757702
# Conectado
# 32 ['tra', 'mtc']
# 2019-09-14 12:29:45.315756
# Conectado
# 33 ['tra', 'mtc']
# 2019-09-14 12:29:48.853011
# Conectado
# 34 ['tra', 'mtc']
# 2019-09-14 12:29:51.321207
# Conectado
# 35 ['tra', 'mtc']
# 2019-09-14 12:29:53.534994
# Conectado
# 36 ['tra', 'mtc']
# 2019-09-14 12:29:55.711474
# Conectado
# 37 ['tra', 'mtc']
# 2019-09-14 12:29:57.988588
# Conectado
# 38 ['tra', 'mtc']
# 2019-09-14 12:30:01.469780
# Conectado
# 39 ['tra', 'mtc']
# 2019-09-14 12:30:03.987186
# Conectado
# 40 ['tra', 'mtc']
# 2019-09-14 12:30:06.176438
# Conectado
# 41 ['tra', 'mtc']
# 2019-09-14 12:30:08.331409
# Conectado
# 42 ['tra', 'mtc']
# 2019-09-14 12:30:10.527331
# Conectado
# 43 ['tra', 'mtc']
# 2019-09-14 12:30:14.619540
# Conectado
# 44 ['tra', 'mtc']
# 2019-09-14 12:30:17.375975
# Conectado
# 45 ['tra', 'mtc']
# 2019-09-14 12:30:19.743246
# Conectado
# 46 ['tra', 'mtc']
# 2019-09-14 12:30:22.682784
# Conectado
# 47 ['tra', 'mtc']
# 2019-09-14 12:30:25.933969
# Conectado
# 48 ['tra', 'mtc']
# 2019-09-14 12:30:28.213955
# Conectado
# 49 ['tra', 'mtc']
# 2019-09-14 12:30:30.447642
# Conectado
# 50 ['tra', 'mtc']
# 2019-09-14 12:30:32.748752
# Conectado
# 51 ['tra', 'mtc']
# 2019-09-14 12:30:35.243844
# Conectado
# 52 ['tra', 'mtc']
# 2019-09-14 12:30:37.965321
# Conectado
# 53 ['tra', 'mtc']
# 2019-09-14 12:30:40.144242
# Conectado
# 54 ['tra', 'mtc']
# 2019-09-14 12:30:42.332931
# Conectado
# 55 ['tra', 'mtc']
# 2019-09-14 12:30:44.521234
# Conectado
# 56 ['tra', 'mtc']
# 2019-09-14 12:30:46.725809
# Conectado
# 57 ['tra', 'mtc']
# 2019-09-14 12:30:49.054047
# Conectado
# 58 ['tra', 'mtc']
# 2019-09-14 12:30:51.871634
# Conectado
# 59 ['tra', 'mtc']
# 2019-09-14 12:30:54.499529
# Conectado
# 60 ['tra', 'mtc']
# 2019-09-14 12:30:57.526309
# Conectado
# 61 ['tra', 'mtc']
# 2019-09-14 12:31:01.904923
# Conectado
# 62 ['tra', 'mtc']
# 2019-09-14 12:31:04.177822
# Conectado
# 63 ['tra', 'mtc']
# 2019-09-14 12:31:07.247249
# Conectado
# 64 ['tra', 'mtc']
# 2019-09-14 12:31:09.782135
# Conectado
# 65 ['tra', 'mtc']
# 2019-09-14 12:31:12.618291
# Conectado
# 66 ['tra', 'mtc']
# 2019-09-14 12:31:14.813829
# Conectado
# 67 ['tra', 'mtc']
# 2019-09-14 12:31:18.601447
# Conectado
# 68 ['tra', 'mtc']
# 2019-09-14 12:31:21.919282
# Conectado
# 69 ['tra', 'mtc']
# 2019-09-14 12:31:25.614397
# Conectado
# 70 ['tra', 'mtc']
# 2019-09-14 12:31:29.762655
# Conectado
# 71 ['tra', 'mtc']
# 2019-09-14 12:31:31.899796
# Conectado
# 72 ['tra', 'mtc']
# 2019-09-14 12:31:34.732217
# Conectado
# 73 ['tra', 'mtc']
# 2019-09-14 12:31:37.669600
# Conectado
# 74 ['tra', 'mtc']
# 2019-09-14 12:31:39.812362
# Conectado
# 75 ['tra', 'mtc']
# 2019-09-14 12:31:42.426054
# Conectado
# 76 ['tra', 'mtc']
# 2019-09-14 12:31:45.778441
# Conectado
# 77 ['tra', 'mtc']
# 2019-09-14 12:31:47.916319
# Conectado
# 78 ['tra', 'mtc']
# 2019-09-14 12:31:51.291585
# Conectado
# 79 ['tra', 'mtc']
# 2019-09-14 12:31:53.591383
# Conectado
# 80 ['tra', 'mtc']
# 2019-09-14 12:31:57.412239
# Conectado
# 81 ['tra', 'mtc']
# 2019-09-14 12:31:59.761593
# Conectado
# 82 ['tra', 'mtc']
# 2019-09-14 12:32:02.366657
# Conectado
# 83 ['tra', 'mtc']
# 2019-09-14 12:32:05.801782
# Conectado
# 84 ['tra', 'mtc']
# 2019-09-14 12:32:09.358510
# Conectado
# 85 ['tra', 'mtc']
# 2019-09-14 12:32:12.472785
# Conectado
# 86 ['tra', 'mtc']
# 2019-09-14 12:32:15.190563
# Conectado
# 87 ['tra', 'mtc']
# 2019-09-14 12:32:19.048873
# Conectado
# 88 ['tra', 'mtc']
# 2019-09-14 12:32:22.152190
# Conectado
# 89 ['tra', 'mtc']
# 2019-09-14 12:32:25.347575
# Conectado
# 90 ['tra', 'mtc']
# 2019-09-14 12:32:27.512917
# Conectado
# 91 ['tra', 'mtc']
# 2019-09-14 12:32:29.701114
# Conectado
# 92 ['tra', 'mtc']
# 2019-09-14 12:32:32.821536
# Conectado
# 93 ['tra', 'mtc']
# 2019-09-14 12:32:35.803487
# Conectado
# 94 ['tra', 'mtc']
# 2019-09-14 12:32:37.954332
# Conectado
# 95 ['tra', 'mtc']
# 2019-09-14 12:32:41.258962
# Conectado
# 96 ['tra', 'mtc']
# 2019-09-14 12:32:43.524885
# Conectado
# 97 ['tra', 'mtc']
# 2019-09-14 12:32:45.740744
# Conectado
# 98 ['tra', 'mtc']
# 2019-09-14 12:32:48.268627
# Conectado
# 99 ['tra', 'mtc']
# 2019-09-14 12:32:50.477659
# Conectado
# 100 ['tra', 'mtc']
# 2019-09-14 12:32:52.629211
# Conectado
# 101 ['tra', 'mtc']
# 2019-09-14 12:32:54.835821
# Conectado
# 102 ['tra', 'mtc']
# 2019-09-14 12:32:56.987386
# Conectado
# 103 ['tra', 'mtc']
# 2019-09-14 12:32:59.161934
# Conectado
# 104 ['tra', 'mtc']
# 2019-09-14 12:33:01.441703
# Conectado
# 105 ['tra', 'mtc']
# 2019-09-14 12:33:03.611897
# Conectado
# 106 ['tra', 'mtc']
# 2019-09-14 12:33:05.849098
# Conectado
# 107 ['tra', 'mtc']
# 2019-09-14 12:33:08.265920
# Conectado
# 108 ['tra', 'mtc']
# 2019-09-14 12:33:10.433802
# Conectado
# 109 ['tra', 'mtc']
# 2019-09-14 12:33:12.607225
# Conectado
# 110 ['tra', 'mtc']
# 2019-09-14 12:33:16.021665
# Conectado
# 111 ['tra', 'mtc']
# 2019-09-14 12:33:18.377724
# Conectado
# 112 ['tra', 'mtc']
# 2019-09-14 12:33:20.963596
# Conectado
# 113 ['tra', 'mtc']
# 2019-09-14 12:33:23.260605
# Conectado
# 114 ['tra', 'mtc']
# 2019-09-14 12:33:26.708104
# Conectado
# 115 ['tra', 'mtc']
# 2019-09-14 12:33:29.085191
# Conectado
# 116 ['tra', 'mtc']
# 2019-09-14 12:33:31.262119
# Conectado
# 117 ['tra', 'mtc']
# 2019-09-14 12:33:33.460485
# Conectado
# 118 ['tra', 'mtc']
# 2019-09-14 12:33:36.645894
# Conectado
# 119 ['tra', 'mtc']
# 2019-09-14 12:33:38.890444
# Conectado
# 120 ['tra', 'mtc']
# 2019-09-14 12:33:41.209871
# Conectado
# 121 ['tra', 'mtc']
# 2019-09-14 12:33:43.408397
# Conectado
# 122 ['tra', 'mtc']
# 2019-09-14 12:33:45.573912
# Conectado
# 123 ['tra', 'mtc']
# 2019-09-14 12:33:47.711160
# Conectado
# 124 ['tra', 'mtc']
# 2019-09-14 12:33:49.887238
# Conectado
# 125 ['tra', 'mtc']
# 2019-09-14 12:33:52.030641
# Conectado
# 126 ['tra', 'mtc']
# 2019-09-14 12:33:54.353404
# Conectado
# 127 ['tra', 'mtc']
# 2019-09-14 12:33:56.536390
# Conectado
# 128 ['tra', 'mtc']
# 2019-09-14 12:33:58.739563
# Conectado
# 129 ['tra', 'mtc']
# 2019-09-14 12:34:01.184835
# Conectado
# 130 ['tra', 'mtc']
# 2019-09-14 12:34:04.819233
# Conectado
# 131 ['tra', 'mtc']
# 2019-09-14 12:34:07.263494
# Conectado
# 132 ['tra', 'mtc']
# 2019-09-14 12:34:09.685531
# Conectado
# 133 ['tra', 'mtc']
# 2019-09-14 12:34:12.053291
# Conectado
# 134 ['tra', 'mtc']
# 2019-09-14 12:34:14.206275
# Conectado
# 135 ['tra', 'mtc']
# 2019-09-14 12:34:16.571186
# Conectado
# 136 ['tra', 'mtc']
# 2019-09-14 12:34:18.710242
# Conectado
# 137 ['tra', 'mtc']
# 2019-09-14 12:34:23.892483
# Conectado
# 138 ['tra', 'mtc']
# 2019-09-14 12:34:26.050784
# Conectado
# 139 ['tra', 'mtc']
# 2019-09-14 12:34:28.171104
# Conectado
# 140 ['tra', 'mtc']
# 2019-09-14 12:34:30.351678
# Conectado
# 141 ['tra', 'mtc']
# 2019-09-14 12:34:32.495731
# Conectado
# 142 ['tra', 'mtc']
# 2019-09-14 12:34:34.661352
# Conectado
# 143 ['tra', 'mtc']
# 2019-09-14 12:34:36.801064
# Conectado
# 144 ['tra', 'mtc']
# 2019-09-14 12:34:38.970412
# Conectado
# 145 ['tra', 'mtc']
# 2019-09-14 12:34:41.323456
# Conectado
# 146 ['tra', 'mtc']
# 2019-09-14 12:34:43.504192
# Conectado
# 147 ['tra', 'mtc']
# 2019-09-14 12:34:45.651778
# Conectado
# 148 ['tra', 'mtc']
# 2019-09-14 12:34:47.769277
# Conectado
# 149 ['tra', 'mtc']
# 2019-09-14 12:34:49.936651
# Conectado
# 150 ['tra', 'mtc']
# 2019-09-14 12:34:52.106812
# Conectado
# 151 ['tra', 'mtc']
# 2019-09-14 12:34:54.271492
# Conectado
# 152 ['tra', 'mtc']
# 2019-09-14 12:34:56.408791
# Conectado
# 153 ['tra', 'mtc']
# 2019-09-14 12:34:58.599253
# Conectado
# 154 ['tra', 'mtc']
# 2019-09-14 12:35:00.764489
# Conectado
# 155 ['tra', 'mtc']
# 2019-09-14 12:35:02.919576
# Conectado
# 156 ['tra', 'mtc']
# 2019-09-14 12:35:05.269258
# Conectado
# 157 ['tra', 'mtc']
# 2019-09-14 12:35:07.443925
# Conectado
# 158 ['tra', 'mtc']
# 2019-09-14 12:35:09.789448
# Conectado
# 159 ['tra', 'mtc']
# 2019-09-14 12:35:11.976018
# Conectado
# 160 ['tra', 'mtc']
# 2019-09-14 12:35:14.365759
# Conectado
# 161 ['tra', 'mtc']
# 2019-09-14 12:35:17.048151
# Conectado
# 162 ['tra', 'mtc']
# 2019-09-14 12:35:19.596615
# Conectado
# 163 ['tra', 'mtc']
# 2019-09-14 12:35:21.767556
# Conectado
# 164 ['tra', 'mtc']
# 2019-09-14 12:35:24.177022
# Conectado
# 165 ['tra', 'mtc']
# 2019-09-14 12:35:27.417835
# Conectado
# 166 ['tra', 'mtc']
# 2019-09-14 12:35:29.996079
# Conectado
# 167 ['tra', 'mtc']
# 2019-09-14 12:35:32.526319
# Conectado
# 168 ['tra', 'mtc']
# 2019-09-14 12:35:34.720297
# Conectado
# 169 ['tra', 'mtc']
# 2019-09-14 12:35:37.204510
# Conectado
# 170 ['tra', 'mtc']
# 2019-09-14 12:35:39.539753
# Conectado
# 171 ['tra', 'mtc']
# 2019-09-14 12:35:41.706844
# Conectado
# 172 ['tra', 'mtc']
# 2019-09-14 12:35:44.147080
# Conectado
# 173 ['tra', 'mtc']
# 2019-09-14 12:35:46.376212
# Conectado
# 174 ['tra', 'mtc']
# 2019-09-14 12:35:48.567031
# Conectado
# 175 ['tra', 'mtc']
# 2019-09-14 12:35:50.786515
# Conectado
# 176 ['tra', 'mtc']
# 2019-09-14 12:35:53.651737
# Conectado
# 177 ['tra', 'mtc']
# 2019-09-14 12:35:55.874161
# Conectado
# 178 ['tra', 'mtc']
# 2019-09-14 12:35:58.058037
# Conectado
# 179 ['tra', 'mtc']
# 2019-09-14 12:36:00.213131
# Conectado
# 180 ['tra', 'mtc']
# 2019-09-14 12:36:04.384009
# Conectado
# 181 ['tra', 'mtc']
# 2019-09-14 12:36:06.648866
# Conectado
# 182 ['tra', 'mtc']
# 2019-09-14 12:36:08.774881
# Conectado
# 183 ['tra', 'mtc']
# 2019-09-14 12:36:11.026069
# Conectado
# 184 ['tra', 'mtc']
# 2019-09-14 12:36:13.258101
# Conectado
# 185 ['tra', 'mtc']
# 2019-09-14 12:36:15.637968
# Conectado
# 186 ['tra', 'mtc']
# 2019-09-14 12:36:17.967739
# Conectado
# 187 ['tra', 'mtc']
# 2019-09-14 12:36:20.486006
# Conectado
# 188 ['tra', 'mtc']
# 2019-09-14 12:36:22.657050
# Conectado
# 189 ['tra', 'mtc']
# 2019-09-14 12:36:24.820194
# Conectado
# 190 ['tra', 'mtc']
# 2019-09-14 12:36:27.943632
# Conectado
# 191 ['tra', 'mtc']
# 2019-09-14 12:36:30.135008
# Conectado
# 192 ['tra', 'mtc']
# 2019-09-14 12:36:32.549185
# Conectado
# 193 ['tra', 'mtc']
# 2019-09-14 12:36:34.904698
# Conectado
# 194 ['tra', 'mtc']
# 2019-09-14 12:36:37.136877
# Conectado
# 195 ['tra', 'mtc']
# 2019-09-14 12:36:39.479025
# Conectado
# 196 ['tra', 'mtc']
# 2019-09-14 12:36:41.652655
# Conectado
# 197 ['tra', 'mtc']
# 2019-09-14 12:36:43.843255
# Conectado
# 198 ['tra', 'mtc']
# 2019-09-14 12:36:45.966998
# Conectado
# 199 ['tra', 'mtc']
# 2019-09-14 12:36:48.164640
# Conectado
# 200 ['tra', 'mtc']
# 2019-09-14 12:36:50.614110
# Conectado
# 201 ['tra', 'mtc']
# 2019-09-14 12:36:53.469059
# Conectado
# 202 ['tra', 'mtc']
# 2019-09-14 12:36:55.653135
# Conectado
# 203 ['tra', 'mtc']
# 2019-09-14 12:36:57.803484
# Conectado
# 204 ['tra', 'mtc']
# 2019-09-14 12:36:59.971381
# Conectado
# 205 ['tra', 'mtc']
# 2019-09-14 12:37:02.153285
# Conectado
# 206 ['tra', 'mtc']
# 2019-09-14 12:37:04.307272
# Conectado
# 207 ['tra', 'mtc']
# 2019-09-14 12:37:07.129111
# Conectado
# 208 ['tra', 'mtc']
# 2019-09-14 12:37:09.483245
# Conectado
# 209 ['tra', 'mtc']
# 2019-09-14 12:37:13.435798
# Conectado
# 210 ['tra', 'mtc']
# 2019-09-14 12:37:15.576357
# Conectado
# 211 ['tra', 'mtc']
# 2019-09-14 12:37:18.292305
# Conectado
# 212 ['tra', 'mtc']
# 2019-09-14 12:37:21.235845
# Conectado
# 213 ['tra', 'mtc']
# 2019-09-14 12:37:23.727144
# Conectado
# 214 ['tra', 'mtc']
# 2019-09-14 12:37:26.102086
# Conectado
# 215 ['tra', 'mtc']
# 2019-09-14 12:37:29.706105
# Conectado
# 216 ['tra', 'mtc']
# 2019-09-14 12:37:32.112460
# Conectado
# 217 ['tra', 'mtc']
# 2019-09-14 12:37:35.559005
# Conectado
# 218 ['tra', 'mtc']
# 2019-09-14 12:37:38.029299
# Conectado
# 219 ['tra', 'mtc']
# 2019-09-14 12:37:41.227521
# Conectado
# 220 ['tra', 'mtc']
# 2019-09-14 12:37:43.366318
# Conectado
# 221 ['tra', 'mtc']
# 2019-09-14 12:37:45.838473
# Conectado
# 222 ['tra', 'mtc']
# 2019-09-14 12:37:48.644773
# Conectado
# 223 ['tra', 'mtc']
# 2019-09-14 12:37:52.122517
# Conectado
# 224 ['tra', 'mtc']
# 2019-09-14 12:37:55.120013
# Conectado
# 225 ['tra', 'mtc']
# 2019-09-14 12:37:57.562769
# Conectado
# 226 ['tra', 'mtc']
# 2019-09-14 12:38:01.091697
# Conectado
# 227 ['tra', 'mtc']
# 2019-09-14 12:38:03.312042
# Conectado
# 228 ['tra', 'mtc']
# 2019-09-14 12:38:06.899752
# Conectado
# 229 ['tra', 'mtc']
# 2019-09-14 12:38:10.859333
# Conectado
# 230 ['tra', 'mtc']
# 2019-09-14 12:38:13.247051
# Conectado
# 231 ['tra', 'mtc']
# 2019-09-14 12:38:15.397686
# Conectado
# 232 ['tra', 'mtc']
# 2019-09-14 12:38:17.528930
# Conectado
# 233 ['tra', 'mtc']
# 2019-09-14 12:38:20.648647
# Conectado
# 234 ['tra', 'mtc']
# 2019-09-14 12:38:23.312623
# Conectado
# 235 ['tra', 'mtc']
# 2019-09-14 12:38:26.318074
# Conectado
# 236 ['tra', 'mtc']
# 2019-09-14 12:38:29.133583
# Conectado
# 237 ['tra', 'mtc']
# 2019-09-14 12:38:32.406994
# Conectado
# 238 ['tra', 'mtc']
# 2019-09-14 12:38:34.573389
# Conectado
# 239 ['tra', 'mtc']
# 2019-09-14 12:38:36.759756
# Conectado
# 240 ['tra', 'mtc']
# 2019-09-14 12:38:38.877274
# Conectado
# 241 ['tra', 'mtc']
# 2019-09-14 12:38:41.039478
# Conectado
# 242 ['tra', 'mtc']
# 2019-09-14 12:38:44.784363
# Conectado
# 243 ['tra', 'mtc']
# 2019-09-14 12:38:47.010270
# Conectado
# 244 ['tra', 'mtc']
# 2019-09-14 12:38:49.186136
# Conectado
# 245 ['tra', 'mtc']
# 2019-09-14 12:38:51.368007
# Conectado
# 246 ['tra', 'mtc']
# 2019-09-14 12:38:53.944150
# Conectado
# 247 ['tra', 'mtc']
# 2019-09-14 12:38:56.088186
# Conectado
# 248 ['tra', 'mtc']
# 2019-09-14 12:38:58.295276
# Conectado
# 249 ['tra', 'mtc']
# 2019-09-14 12:39:00.463662
# Conectado
# 250 ['tra', 'mtc']
# 2019-09-14 12:39:03.168382
# Conectado
# 251 ['tra', 'mtc']
# 2019-09-14 12:39:05.336330
# Conectado
# 252 ['tra', 'mtc']
# 2019-09-14 12:39:07.507204
# Conectado
# 253 ['tra', 'mtc']
# 2019-09-14 12:39:09.653702
# Conectado
# 254 ['tra', 'mtc']
# 2019-09-14 12:39:11.827224
# Conectado
# 255 ['tra', 'mtc']
# 2019-09-14 12:39:13.991456
# Conectado
# 256 ['tra', 'mtc']
# 2019-09-14 12:39:16.147475
# Conectado
# 257 ['tra', 'mtc']
# 2019-09-14 12:39:18.298696
# Conectado
# 258 ['tra', 'mtc']
# 2019-09-14 12:39:20.574048
# Conectado
# 259 ['tra', 'mtc']
# 2019-09-14 12:39:22.726876
# Conectado
# 260 ['tra', 'mtc']
# 2019-09-14 12:39:24.906810
# Conectado
# 261 ['tra', 'mtc']
# 2019-09-14 12:39:27.077006
# Conectado
# 262 ['tra', 'mtc']
# 2019-09-14 12:39:29.410976
# Conectado
# 263 ['tra', 'mtc']
# 2019-09-14 12:39:31.579806
# Conectado
# 264 ['tra', 'mtc']
# 2019-09-14 12:39:33.746740
# Conectado
# 265 ['tra', 'mtc']
# 2019-09-14 12:39:36.818171
# Conectado
# 266 ['tra', 'mtc']
# 2019-09-14 12:39:38.973343
# Conectado
# 267 ['tra', 'mtc']
# 2019-09-14 12:39:41.203293
# Conectado
# 268 ['tra', 'mtc']
# 2019-09-14 12:39:43.364678
# Conectado
# 269 ['tra', 'mtc']
# 2019-09-14 12:39:45.516527
# Conectado
# 270 ['tra', 'mtc']
# 2019-09-14 12:39:47.694882
# Conectado
# 271 ['tra', 'mtc']
# 2019-09-14 12:39:50.054274
# Conectado
# 272 ['tra', 'mtc']
# 2019-09-14 12:39:52.223187
# Conectado
# 273 ['tra', 'mtc']
# 2019-09-14 12:39:54.428966
# Conectado

# %%
df_tramites=df_tramites_link[df_tramites_link.link!='Sin página'].reset_index().drop(columns=['index'])

# %%
ministerios = [] ; id_entidad = [] ; id_registro = [] ; tipo_registro = [] ; tipo_acceso = [];
for i in range(len(df_tramites)):
    ltra=len(str(df_tramites.tramite[i]))
    ministerios.append(str(df_tramites.ministerio[i])[ltra:])
    
    id_pagina = str(df_tramites.link[i])[58:]
    id_entidad.append(re.search(r'([0-9]*[0-9])',re.search(r'(id_entidad.*)', id_pagina).group(0)).group(0)) # id entidad
    id_registro.append(re.search(r'([0-9]*[0-9])',re.search(r'(id_registro.*)', id_pagina).group(0)).group(0)) # id registro
    tipo_registro.append(re.search(r'([A-Z])',re.search(r'(=.*&)',re.search(r'(tipo_registro.*)', id_pagina).group(0)).group(0)).group(0)) # tipo registro
    tipo_acceso.append(re.search(r'([A-Z])',re.search(r'(tipo_acceso.*)', id_pagina).group(0)).group(0)) # tipo acceso
identidad_registro = pd.DataFrame({'entidad':ministerios,'id_entidad':id_entidad,'id_registro':id_registro,'tipo_registro':tipo_registro,'tipo_acceso':tipo_acceso})
df_tramites_final = pd.concat([identidad_registro,df_tramites],axis=1)

# %%
df_tramites_final.columns
# Out:
# Index(['entidad', 'id_entidad', 'id_registro', 'tipo_registro', 'tipo_acceso',
#        'id_search', 'word_key', 'id_link', 'link', 'tramite', 'ministerio',
#        'time_update'],
#       dtype='object')

# %%
df_tramites_final.to_csv('DataSet/df_tramites_link.csv',sep='|',encoding='utf8',index_label=False,index=False)

# %% [markdown]
# # Data de cada trámite

# %%
df_tramites_final=pd.read_csv('DataSet/df_tramites_link.csv',sep='|',encoding='utf8')

# %%
df_tramites_final.groupby('tipo_registro').count()
# Out:
#                entidad  id_entidad  id_registro  tipo_acceso  id_search  \
# tipo_registro
# F                  185         185          185          185        185
# S                  157         157          157          157        157
# T                 7845        7845         7845         7845       7845
#
#                word_key  id_link  link  tramite  ministerio  time_update
# tipo_registro
# F                   185      185   185      185         185          185
# S                   157      157   157      157         157          157
# T                  7845     7845  7845     7845        7845         7845

# %%
df_tramites_final[df_tramites_final.tipo_registro=='T']
# Out:
#                                                entidad  id_entidad  \
# 3     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 4     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 5     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 6     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 7     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 8     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 9     Ministerio de Transportes y Comunicaciones (MTC)       13306
# 10    Ministerio de Transportes y Comunicaciones (MTC)         144
# 11    Ministerio de Transportes y Comunicaciones (MTC)         144
# 12    Ministerio de Transportes y Comunicaciones (MTC)         144
# 13    Ministerio de Transportes y Comunicaciones (MTC)         144
# 14    Ministerio de Transportes y Comunicaciones (MTC)         144
# 15    Ministerio de Transportes y Comunicaciones (MTC)         144
# 16    Ministerio de Transportes y Comunicaciones (MTC)         144
# 17    Ministerio de Transportes y Comunicaciones (MTC)         144
# 18    Ministerio de Transportes y Comunicaciones (MTC)         144
# 19    Ministerio de Transportes y Comunicaciones (MTC)         144
# 20    Ministerio de Transportes y Comunicaciones (MTC)         144
# 21    Ministerio de Transportes y Comunicaciones (MTC)         144
# 22    Ministerio de Transportes y Comunicaciones (MTC)         144
# 23    Ministerio de Transportes y Comunicaciones (MTC)         144
# 24    Ministerio de Transportes y Comunicaciones (MTC)       10367
# 25    Ministerio de Transportes y Comunicaciones (MTC)       10367
# 26    Ministerio de Transportes y Comunicaciones (MTC)       10367
# 27    Ministerio de Transportes y Comunicaciones (MTC)       10367
# 367   Ministerio de Transportes y Comunicaciones (MTC)       11085
# 368   Ministerio de Transportes y Comunicaciones (MTC)       11085
# 369   Ministerio de Transportes y Comunicaciones (MTC)       10449
# 370   Ministerio de Transportes y Comunicaciones (MTC)       11886
# 371   Ministerio de Transportes y Comunicaciones (MTC)       13300
# ...                                                ...         ...
# 8157  Ministerio de Transportes y Comunicaciones (MTC)       10077
# 8158  Ministerio de Transportes y Comunicaciones (MTC)         141
# 8159  Ministerio de Transportes y Comunicaciones (MTC)         180
# 8160  Ministerio de Transportes y Comunicaciones (MTC)       10147
# 8161  Ministerio de Transportes y Comunicaciones (MTC)       13300
# 8162  Ministerio de Transportes y Comunicaciones (MTC)       14198
# 8163  Ministerio de Transportes y Comunicaciones (MTC)       13832
# 8164  Ministerio de Transportes y Comunicaciones (MTC)       10149
# 8165  Ministerio de Transportes y Comunicaciones (MTC)       10166
# 8166  Ministerio de Transportes y Comunicaciones (MTC)         143
# 8167  Ministerio de Transportes y Comunicaciones (MTC)       10337
# 8168  Ministerio de Transportes y Comunicaciones (MTC)       10331
# 8169  Ministerio de Transportes y Comunicaciones (MTC)       12217
# 8170  Ministerio de Transportes y Comunicaciones (MTC)       11438
# 8171  Ministerio de Transportes y Comunicaciones (MTC)       10314
# 8172  Ministerio de Transportes y Comunicaciones (MTC)       12196
# 8173  Ministerio de Transportes y Comunicaciones (MTC)       11410
# 8174  Ministerio de Transportes y Comunicaciones (MTC)       11824
# 8175  Ministerio de Transportes y Comunicaciones (MTC)       11824
# 8176  Ministerio de Transportes y Comunicaciones (MTC)       10401
# 8177  Ministerio de Transportes y Comunicaciones (MTC)        1710
# 8178  Ministerio de Transportes y Comunicaciones (MTC)       10166
# 8179  Ministerio de Transportes y Comunicaciones (MTC)          94
# 8180  Ministerio de Transportes y Comunicaciones (MTC)         183
# 8181  Ministerio de Transportes y Comunicaciones (MTC)       10487
# 8182  Ministerio de Transportes y Comunicaciones (MTC)       10504
# 8183  Ministerio de Transportes y Comunicaciones (MTC)       12139
# 8184  Ministerio de Transportes y Comunicaciones (MTC)       10505
# 8185  Ministerio de Transportes y Comunicaciones (MTC)       13982
# 8186  Ministerio de Transportes y Comunicaciones (MTC)       10520
#
#       id_registro tipo_registro tipo_acceso  id_search   word_key  id_link  \
# 3           42746             T           B          0  tra%20mtc        7
# 4           42747             T           B          0  tra%20mtc        8
# 5           42751             T           B          0  tra%20mtc        9
# 6           42765             T           B          0  tra%20mtc       10
# 7           42766             T           B          0  tra%20mtc       11
# 8           42764             T           B          0  tra%20mtc       12
# 9           42763             T           B          0  tra%20mtc       13
# 10            823             T           B          0  tra%20mtc       14
# 11            799             T           B          0  tra%20mtc       15
# 12            790             T           B          0  tra%20mtc       16
# 13            814             T           B          0  tra%20mtc       17
# 14            806             T           B          0  tra%20mtc       18
# 15            822             T           B          0  tra%20mtc       19
# 16            802             T           B          0  tra%20mtc       20
# 17            797             T           B          0  tra%20mtc       21
# 18            795             T           B          0  tra%20mtc       22
# 19            792             T           B          0  tra%20mtc       23
# 20            788             T           B          0  tra%20mtc       24
# 21            785             T           B          0  tra%20mtc       25
# 22            783             T           B          0  tra%20mtc       26
# 23            809             T           B          0  tra%20mtc       27
# 24          84049             T           B          0  tra%20mtc       28
# 25          84058             T           B          0  tra%20mtc       29
# 26          84024             T           B          0  tra%20mtc       30
# 27          25431             T           B          0  tra%20mtc       31
# 367         86706             T           B         12  tra%20mtc       11
# 368         86776             T           B         12  tra%20mtc       12
# 369         58080             T           B         12  tra%20mtc       13
# 370         90344             T           B         12  tra%20mtc       14
# 371         11106             T           B         12  tra%20mtc       15
# ...           ...           ...         ...        ...        ...      ...
# 8157        24083             T           B        272  tra%20mtc        3
# 8158        98721             T           B        272  tra%20mtc        4
# 8159        73321             T           B        272  tra%20mtc        5
# 8160        75227             T           B        272  tra%20mtc        6
# 8161        10948             T           B        272  tra%20mtc        7
# 8162        54548             T           B        272  tra%20mtc        8
# 8163        34543             T           B        272  tra%20mtc        9
# 8164        98566             T           B        272  tra%20mtc       10
# 8165        64097             T           B        272  tra%20mtc       11
# 8166        28030             T           B        272  tra%20mtc       12
# 8167        46413             T           B        272  tra%20mtc       13
# 8168        70578             T           B        272  tra%20mtc       14
# 8169        66627             T           B        272  tra%20mtc       15
# 8170        34783             T           B        272  tra%20mtc       16
# 8171        41458             T           B        272  tra%20mtc       17
# 8172        45587             T           B        272  tra%20mtc       18
# 8173        41901             T           B        272  tra%20mtc       19
# 8174        19699             T           B        272  tra%20mtc       20
# 8175        19700             T           B        272  tra%20mtc       21
# 8176        21074             T           B        272  tra%20mtc       22
# 8177        90513             T           B        272  tra%20mtc       23
# 8178        64627             T           B        272  tra%20mtc       24
# 8179        56537             T           B        272  tra%20mtc       25
# 8180         2731             T           B        272  tra%20mtc       26
# 8181        42111             T           B        272  tra%20mtc       27
# 8182        39727             T           B        272  tra%20mtc       28
# 8183        37721             T           B        272  tra%20mtc       29
# 8184        43766             T           B        272  tra%20mtc       30
# 8185        62903             T           B        272  tra%20mtc       31
# 8186        42416             T           B        273  tra%20mtc        2
#
#                                                    link  \
# 3     https://www.tramites.gob.pe/buscador/psce_reg_...
# 4     https://www.tramites.gob.pe/buscador/psce_reg_...
# 5     https://www.tramites.gob.pe/buscador/psce_reg_...
# 6     https://www.tramites.gob.pe/buscador/psce_reg_...
# 7     https://www.tramites.gob.pe/buscador/psce_reg_...
# 8     https://www.tramites.gob.pe/buscador/psce_reg_...
# 9     https://www.tramites.gob.pe/buscador/psce_reg_...
# 10    https://www.tramites.gob.pe/buscador/psce_reg_...
# 11    https://www.tramites.gob.pe/buscador/psce_reg_...
# 12    https://www.tramites.gob.pe/buscador/psce_reg_...
# 13    https://www.tramites.gob.pe/buscador/psce_reg_...
# 14    https://www.tramites.gob.pe/buscador/psce_reg_...
# 15    https://www.tramites.gob.pe/buscador/psce_reg_...
# 16    https://www.tramites.gob.pe/buscador/psce_reg_...
# 17    https://www.tramites.gob.pe/buscador/psce_reg_...
# 18    https://www.tramites.gob.pe/buscador/psce_reg_...
# 19    https://www.tramites.gob.pe/buscador/psce_reg_...
# 20    https://www.tramites.gob.pe/buscador/psce_reg_...
# 21    https://www.tramites.gob.pe/buscador/psce_reg_...
# 22    https://www.tramites.gob.pe/buscador/psce_reg_...
# 23    https://www.tramites.gob.pe/buscador/psce_reg_...
# 24    https://www.tramites.gob.pe/buscador/psce_reg_...
# 25    https://www.tramites.gob.pe/buscador/psce_reg_...
# 26    https://www.tramites.gob.pe/buscador/psce_reg_...
# 27    https://www.tramites.gob.pe/buscador/psce_reg_...
# 367   https://www.tramites.gob.pe/buscador/psce_reg_...
# 368   https://www.tramites.gob.pe/buscador/psce_reg_...
# 369   https://www.tramites.gob.pe/buscador/psce_reg_...
# 370   https://www.tramites.gob.pe/buscador/psce_reg_...
# 371   https://www.tramites.gob.pe/buscador/psce_reg_...
# ...                                                 ...
# 8157  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8158  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8159  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8160  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8161  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8162  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8163  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8164  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8165  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8166  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8167  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8168  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8169  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8170  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8171  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8172  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8173  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8174  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8175  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8176  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8177  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8178  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8179  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8180  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8181  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8182  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8183  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8184  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8185  https://www.tramites.gob.pe/buscador/psce_reg_...
# 8186  https://www.tramites.gob.pe/buscador/psce_reg_...
#
#                                                 tramite  \
# 3     AUTORIZACIÓN PARA LA INSTALACIÓN DE INFRAESTRU...
# 4     CONFORMIDAD Y FINALIZACION DE LA EJECUCION DE ...
# 5     DECLARACION DE PROPIEDAD POR REGULARIZACION DE...
# 6     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 7     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 8     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 9     EXPEDICION DE AUTORIZACION PROVISIONAL DE RUTA...
# 10    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 11    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 12    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 13    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 14    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 15    PERMISO DE OPERACIÓN (OTRAS ACTIVIDADES AERONÁ...
# 16    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 17    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 18    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 19    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 20    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 21    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 22    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 23                   PERMISO DE OPERACIÓN-TRABAJO AÉREO
# 24    TRANSFERECNIA DE LA AUTORIZACIÓN O HABILITACIÓ...
# 25    TRANSFERENCIA DE LA AUTORIZACIÓN O HABILITACIÓ...
# 26    TRANSFERENCIA DE VEHÍCULO HABILITADO (SOLO PAR...
# 27    TRANSFERENCIA DE VEHÍCULO HABILITADO (SOLO PAR...
# 367      B) DECLARACIÓN JURADA DE TRANSFERENCIA O DE...
# 368      LICENCIA DE EDIFICACION MODALIDAD D APROBAC...
# 369    - TITULO PROFESIONAL O GRADO DE BACHILLER (PA...
# 370    A)  CANCELACIÓN  DE  ACTAS  REGISTRALES  INSC...
# 371    ACTA DE CONCILIACION CELEBRADA CON LA INTERVE...
# ...                                                 ...
# 8157  VISACIÓN DE PLANOS. BASE LEGAL LEY 23853 ART. ...
# 8158  VISACIÓN DEL CERTIFICADO DE TRABAJO  PARA ADQU...
# 8159  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA  ADQU...
# 8160  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8161  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8162  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8163  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8164  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8165  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8166  VISACIÓN DEL LIBRO DE CONTROL DE  ESTUPEFACIEN...
# 8167  VISACION, RECTIFICACION Y/O  CORRECCIÓN DE DOC...
# 8168  VISACION, RECTIFICACIÓN Y/O CORRECCIÓN DE DOCU...
# 8169  VISACION, RECTIFICACIÓN Y/O CORRECCIÓN DE DOCU...
# 8170  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8171  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8172  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8173  VISACIÓN, RECTIFICACIÓN Y/O CORRECIÓN DE DOCUM...
# 8174  VISACIONES DE PLANOS Y MEMORIA DESCRIPTIVA PAR...
# 8175  VISACIONES DE PLANOS Y MEMORIA DESCRIPTIVA PAR...
# 8176           VISACIONES POR SILABO PARA EL EXTRANJERO
# 8177  VISE  DE ACUERDO AL PLAN ESTRATÉGICO DE LA OFI...
# 8178  VISITA DE VERIFICACIÓN DE SUBSANACIÓN DE NO CO...
# 8179  VISUALIZACIÓN DE EXPEDIENTE EN PANTALLA EN MÓD...
# 8180  VISUALIZACIÓN DE PARTIDAS REGISTRALES QUE CONT...
# 8181  VIZACION     DE      PLANOS    PARA    TRAMITE...
# 8182   VIZACION DE PLANOS PARA TRAMITE JUDICIAL U OTROS
# 8183  VIZACION DE PLANOS PARA TRAMITE JUDICIAL Y OTROS.
# 8184  VIZACION DE PLANOS PARA TRAMITE JUDICIAL Y/U O...
# 8185  VIZACIÓN DE PLANOS PARA TRAMITE JUDICIAL Y/U O...
# 8186  VIZACION DE PLANOS Y MEMORIA DESCRIPTIVA PARA ...
#
#                                              ministerio  \
# 3     AUTORIZACIÓN PARA LA INSTALACIÓN DE INFRAESTRU...
# 4     CONFORMIDAD Y FINALIZACION DE LA EJECUCION DE ...
# 5     DECLARACION DE PROPIEDAD POR REGULARIZACION DE...
# 6     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 7     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 8     EXPEDICION DE AUTORIZACION DE CIRCULACION PROV...
# 9     EXPEDICION DE AUTORIZACION PROVISIONAL DE RUTA...
# 10    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 11    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 12    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 13    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 14    MODIFICACIÓN O RENOVACIÓN DE PERMISO DE OPERAC...
# 15    PERMISO DE OPERACIÓN (OTRAS ACTIVIDADES AERONÁ...
# 16    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 17    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 18    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 19    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 20    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 21    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 22    PERMISO DE OPERACIÓN-SERVICIO DE TRANSPORTE AÉ...
# 23    PERMISO DE OPERACIÓN-TRABAJO AÉREOMinisterio d...
# 24    TRANSFERECNIA DE LA AUTORIZACIÓN O HABILITACIÓ...
# 25    TRANSFERENCIA DE LA AUTORIZACIÓN O HABILITACIÓ...
# 26    TRANSFERENCIA DE VEHÍCULO HABILITADO (SOLO PAR...
# 27    TRANSFERENCIA DE VEHÍCULO HABILITADO (SOLO PAR...
# 367      B) DECLARACIÓN JURADA DE TRANSFERENCIA O DE...
# 368      LICENCIA DE EDIFICACION MODALIDAD D APROBAC...
# 369    - TITULO PROFESIONAL O GRADO DE BACHILLER (PA...
# 370    A)  CANCELACIÓN  DE  ACTAS  REGISTRALES  INSC...
# 371    ACTA DE CONCILIACION CELEBRADA CON LA INTERVE...
# ...                                                 ...
# 8157  VISACIÓN DE PLANOS. BASE LEGAL LEY 23853 ART. ...
# 8158  VISACIÓN DEL CERTIFICADO DE TRABAJO  PARA ADQU...
# 8159  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA  ADQU...
# 8160  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8161  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8162  VISACION DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8163  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8164  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8165  VISACIÓN DEL CERTIFICADO DE TRABAJO PARA ADQUI...
# 8166  VISACIÓN DEL LIBRO DE CONTROL DE  ESTUPEFACIEN...
# 8167  VISACION, RECTIFICACION Y/O  CORRECCIÓN DE DOC...
# 8168  VISACION, RECTIFICACIÓN Y/O CORRECCIÓN DE DOCU...
# 8169  VISACION, RECTIFICACIÓN Y/O CORRECCIÓN DE DOCU...
# 8170  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8171  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8172  VISACION, RECTIFICACION Y/O CORRECCIÓN DE DOCU...
# 8173  VISACIÓN, RECTIFICACIÓN Y/O CORRECIÓN DE DOCUM...
# 8174  VISACIONES DE PLANOS Y MEMORIA DESCRIPTIVA PAR...
# 8175  VISACIONES DE PLANOS Y MEMORIA DESCRIPTIVA PAR...
# 8176  VISACIONES POR SILABO PARA EL EXTRANJEROUniver...
# 8177  VISE  DE ACUERDO AL PLAN ESTRATÉGICO DE LA OFI...
# 8178  VISITA DE VERIFICACIÓN DE SUBSANACIÓN DE NO CO...
# 8179  VISUALIZACIÓN DE EXPEDIENTE EN PANTALLA EN MÓD...
# 8180  VISUALIZACIÓN DE PARTIDAS REGISTRALES QUE CONT...
# 8181  VIZACION     DE      PLANOS    PARA    TRAMITE...
# 8182  VIZACION DE PLANOS PARA TRAMITE JUDICIAL U OTR...
# 8183  VIZACION DE PLANOS PARA TRAMITE JUDICIAL Y OTR...
# 8184  VIZACION DE PLANOS PARA TRAMITE JUDICIAL Y/U O...
# 8185  VIZACIÓN DE PLANOS PARA TRAMITE JUDICIAL Y/U O...
# 8186  VIZACION DE PLANOS Y MEMORIA DESCRIPTIVA PARA ...
#
#                      time_update
# 3     2019-09-14 12:28:09.865456
# 4     2019-09-14 12:28:09.867486
# 5     2019-09-14 12:28:09.869478
# 6     2019-09-14 12:28:09.870480
# 7     2019-09-14 12:28:09.872481
# 8     2019-09-14 12:28:09.874433
# 9     2019-09-14 12:28:09.875459
# 10    2019-09-14 12:28:09.876455
# 11    2019-09-14 12:28:09.877454
# 12    2019-09-14 12:28:09.878451
# 13    2019-09-14 12:28:09.879447
# 14    2019-09-14 12:28:09.880414
# 15    2019-09-14 12:28:09.882412
# 16    2019-09-14 12:28:09.883446
# 17    2019-09-14 12:28:09.885435
# 18    2019-09-14 12:28:09.886432
# 19    2019-09-14 12:28:09.888447
# 20    2019-09-14 12:28:09.890455
# 21    2019-09-14 12:28:09.891386
# 22    2019-09-14 12:28:09.892413
# 23    2019-09-14 12:28:09.893412
# 24    2019-09-14 12:28:09.894408
# 25    2019-09-14 12:28:09.895404
# 26    2019-09-14 12:28:09.896402
# 27    2019-09-14 12:28:09.897370
# 367   2019-09-14 12:28:47.830453
# 368   2019-09-14 12:28:47.832435
# 369   2019-09-14 12:28:47.833429
# 370   2019-09-14 12:28:47.834426
# 371   2019-09-14 12:28:47.835426
# ...                          ...
# 8157  2019-09-14 12:39:54.392091
# 8158  2019-09-14 12:39:54.393058
# 8159  2019-09-14 12:39:54.395053
# 8160  2019-09-14 12:39:54.398061
# 8161  2019-09-14 12:39:54.399061
# 8162  2019-09-14 12:39:54.401067
# 8163  2019-09-14 12:39:54.402064
# 8164  2019-09-14 12:39:54.403061
# 8165  2019-09-14 12:39:54.403061
# 8166  2019-09-14 12:39:54.404061
# 8167  2019-09-14 12:39:54.405056
# 8168  2019-09-14 12:39:54.406056
# 8169  2019-09-14 12:39:54.407051
# 8170  2019-09-14 12:39:54.408050
# 8171  2019-09-14 12:39:54.409044
# 8172  2019-09-14 12:39:54.411012
# 8173  2019-09-14 12:39:54.414019
# 8174  2019-09-14 12:39:54.416011
# 8175  2019-09-14 12:39:54.417028
# 8176  2019-09-14 12:39:54.418022
# 8177  2019-09-14 12:39:54.419020
# 8178  2019-09-14 12:39:54.420019
# 8179  2019-09-14 12:39:54.421014
# 8180  2019-09-14 12:39:54.422013
# 8181  2019-09-14 12:39:54.423009
# 8182  2019-09-14 12:39:54.423009
# 8183  2019-09-14 12:39:54.424005
# 8184  2019-09-14 12:39:54.425011
# 8185  2019-09-14 12:39:54.426968
# 8186  2019-09-14 12:39:56.534173
#
# [7845 rows x 12 columns]

# %%
url = "https://www.tramites.gob.pe/tramites/psce_ficha_tramite.aspx?id_entidad=144&id_tramite=823"
r = requests.get(url , verify=False)
if (r.status_code==200):
    print('Conectado')
    html = BeautifulSoup(r.text, "html.parser")
else: print('no se conectó')
# Out:
# Conectado

# %%
import codecs
import os
from selenium import webdriver

# %%
def get_browser():
    browser = webdriver.Chrome()
    return browser
#browser = get_browser()

# %%
df_tramites_final=df_tramites_final[df_tramites_final.tipo_registro=='T'].sort_values(by=['id_entidad','id_registro'])

# %%
df_tramites_final = df_tramites_final[(df_tramites_final.id_entidad>=11601)&(df_tramites_final.id_registro>33120)]

# %%
save_path = os.path.expanduser('DataSet/tramites html/')

for id_ent,id_tra in zip(df_tramites_final.id_entidad,df_tramites_final.id_registro):
    browser = get_browser()
    url = "https://www.tramites.gob.pe/tramites/psce_ficha_tramite.aspx?id_entidad="+str(id_ent)+"&id_tramite="+ str(id_tra)
    file_name = 'vb_ent_'+ str(id_ent) + '_tra_' + str(id_tra) + '.html'
    browser.get(url)
    complete_name = os.path.join(save_path, file_name)
    file_object = codecs.open(complete_name, "w", "utf-8")
    html = browser.page_source
    file_object.write(html)
    browser.close()

# %%
df_tramites_final[(df_tramites_final.id_entidad>=10077)&(df_tramites_final.id_registro>24129)]
